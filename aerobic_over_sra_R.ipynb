# %%
library(ggplot2)
library(data.table)
theme_set(theme_bw())
# Out:
# Warning message:
# “package ‘data.table’ was built under R version 4.1.1”

# %%
d = fread('aerobic_sra_for_R.csv')
d[1:3]
# Out:
#   V1 run        key         value
# 1 29 ERR2867973 acc         ERR2867973
# 2 30 ERR2867973 assay_type  WGA
# 3 31 ERR2867973 center_name MAX PLANCK INSTITUTE FOR DEVELOPMENTAL BIOLOGY
#   aerobe_count anaerobe_count aerobe_fraction
# 1 4            17             0.1904762
# 2 4            17             0.1904762
# 3 4            17             0.1904762

# %%
qplot(data=d[key=='organism'], aerobe_fraction, geom='density')
# Out:
# plot without title

# %%
qplot(data=d[key=='organism'][value %in% c('soil metagenome','human gut metagenome','marine metagenome','sediment metagenome')], xlab='Fraction of community that is aerobic (%)', colour=value, aerobe_fraction*100, geom='density')+facet_wrap(~value, scales='free_y')+ theme(legend.position="none")
library(svglite)
ggsave('plots/4_environments_aerobic.svg')
# Out:
# Saving 6.67 x 6.67 in image
# plot without title
